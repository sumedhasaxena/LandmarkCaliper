# %%
import sys
import matplotlib
# %matplotlib inline

sys.path.append('..')
sys.path.append('../model')

from landmarkcaliper import LandmarkCaliper

# %%
image1 = '../data/patient5/input/Sudhir_1.jpeg'

caliper1 = LandmarkCaliper()

caliper1.measure(image1)

# %%
caliper1.show_measurement_details()
# Out:
# Landmark measurements for Sudhir_1.jpeg (cm)
#
# Hand Type: RIGHT, Length: 20.18 cm b/w WRIST to MIDDLE_TIP
# Landmark Measurements:
#      MODEL_TYPE HAND_TYPE  LANDMARK_1  LANDMARK_2  LANDMARK1_ID  LANDMARK2_ID  \
# 0   A4_CONTOURS     RIGHT       WRIST   THUMB_CMC             0             1
# 1   A4_CONTOURS     RIGHT       WRIST   INDEX_MCP             0             5
# 2   A4_CONTOURS     RIGHT       WRIST  MIDDLE_MCP             0             9
# 3   A4_CONTOURS     RIGHT       WRIST    RING_MCP             0            13
# 4   A4_CONTOURS     RIGHT       WRIST   PINKY_MCP             0            17
# 5   A4_CONTOURS     RIGHT   THUMB_CMC   THUMB_MCP             1             2
# 6   A4_CONTOURS     RIGHT   THUMB_MCP    THUMB_IP             2             3
# 7   A4_CONTOURS     RIGHT    THUMB_IP   THUMB_TIP             3             4
# 8   A4_CONTOURS     RIGHT   INDEX_MCP   INDEX_PIP             5             6
# ...

# %%
caliper1.show_hand_landmark_image()

# %%
caliper1.show_a4_contours_image()

# %%
output_dir = None # use default directory for saving output

caliper1.save_measurements(hand_measurements = True, landmark_measurements = True,
                           landmark_display = True, contour_display = True, output_dir = output_dir)
# Out:
# ['/Users/Sudhir/Study/MedicalResearch/HandLandmarkDetection/src/data/patient5/output/Sudhir_1_right_hand_measurements.csv',
#  '/Users/Sudhir/Study/MedicalResearch/HandLandmarkDetection/src/data/patient5/output/Sudhir_1_right_landmark_measurements.csv',
#  '/Users/Sudhir/Study/MedicalResearch/HandLandmarkDetection/src/data/patient5/output/Sudhir_1_right_landmarks.jpeg',
#  '/Users/Sudhir/Study/MedicalResearch/HandLandmarkDetection/src/data/patient5/output/Sudhir_1_right_contours.jpeg']
