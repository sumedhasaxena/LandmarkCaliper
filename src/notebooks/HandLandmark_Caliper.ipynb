# %% [markdown]
# # Landmark Caliper
#
# The Landmark Caliper is designed to help stroke patients during thir rehabilitation, who have suffered loss in motor functions, especially in the movement of hand or fingers.
#
# During rehabilitation, patients are provided with a robotic glove that they wear on the affected hand. These gloves help facilitate movement of affected hand and help patients to regain activity in the affected areas. Since each patient has unique hand geometry, these gloves needs to be of custom fit to achieve best results.
#
# The Landmark Caliper helps in getting measurement for patients in a faster and reliable way by leveraging Machine Learning and advanced image processing techniques. The application detects location of joints in the image and produces measurements of various joints in centimeter. Measurement between two joins is the Euclidean distance.
#
# # Landmark Description
#
# The model detects the keypoint localization of 21 hand-knuckle coordinates within the detected hand regions.
#
# ![hand-landmarks.png](attachment:13d9ec74-e570-47e6-acf5-405f2ee6dab7.png)
#
# # Landmark Caliper Input
#
# The Landmark Caliper takes the patient's hand image taken on a A-4 paper, with palm facing downward.
#
# # Landmark Caliper Output
#
# The Landmark Caliper produces following output:
#
# 1. Hand Measurements
#    - This CSV file contains details of patient's hand type (Left or Right) and selected landmark distances measured in centimeters.
#
# 2. Landmark Measurements
#    - This CSV file contains details of patient's hand type (Left or Right) and all landmark distances measured in centimeters (for each pair of landmarks).
#
# 3. Landmark Image
#    - Landmark drawn on the image with landmark distances
#
# 4. Contour Image
#    - Detected A4 contours drawn on the image

# %%
from notebookcaliper import NotebookCaliper

caliper = NotebookCaliper()
# select file
caliper.choose_file()
# Out:
# FileChooser(path='C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data', filename='', title='<b>Select …

# %%
# run model on selected file
caliper.run_model()
# Out:
# **** Landmark measurements for hand_patient12_7.jpeg (cm) ****
#
# Hand Type: Left, Length: 18.48 cm b/w WRIST to MIDDLE_TIP
# Landmark Measurements:
#      MODEL_TYPE HAND_TYPE  LANDMARK_1  LANDMARK_2  LANDMARK1_ID  LANDMARK2_ID  \
# 0   A4_CONTOURS      Left       WRIST   THUMB_CMC             0             1
# 1   A4_CONTOURS      Left       WRIST   INDEX_MCP             0             5
# 2   A4_CONTOURS      Left       WRIST  MIDDLE_MCP             0             9
# 3   A4_CONTOURS      Left       WRIST    RING_MCP             0            13
# 4   A4_CONTOURS      Left       WRIST   PINKY_MCP             0            17
# 5   A4_CONTOURS      Left   THUMB_CMC   THUMB_MCP             1             2
# 6   A4_CONTOURS      Left   THUMB_MCP    THUMB_IP             2             3
# 7   A4_CONTOURS      Left    THUMB_IP   THUMB_TIP             3             4
# 8   A4_CONTOURS      Left   INDEX_MCP   INDEX_PIP             5             6
# 9   A4_CONTOURS      Left   INDEX_PIP   INDEX_DIP             6             7
# 10  A4_CONTOURS      Left   INDEX_DIP   INDEX_TIP             7             8
# 11  A4_CONTOURS      Left   INDEX_MCP  MIDDLE_MCP             5             9
# 12  A4_CONTOURS      Left  MIDDLE_MCP  MIDDLE_PIP             9            10
# 13  A4_CONTOURS      Left  MIDDLE_PIP  MIDDLE_DIP            10            11
# 14  A4_CONTOURS      Left  MIDDLE_DIP  MIDDLE_TIP            11            12
# 15  A4_CONTOURS      Left  MIDDLE_MCP    RING_MCP             9            13
# 16  A4_CONTOURS      Left    RING_MCP    RING_PIP            13            14
# 17  A4_CONTOURS      Left    RING_PIP    RING_DIP            14            15
# 18  A4_CONTOURS      Left    RING_DIP    RING_TIP            15            16
# 19  A4_CONTOURS      Left    RING_MCP   PINKY_MCP            13            17
# 20  A4_CONTOURS      Left   PINKY_MCP   PINKY_PIP            17            18
# 21  A4_CONTOURS      Left   PINKY_PIP   PINKY_DIP            18            19
# 22  A4_CONTOURS      Left   PINKY_DIP   PINKY_TIP            19            20
# 23  A4_CONTOURS      Left       WRIST   THUMB_TIP             0             4
# 24  A4_CONTOURS      Left       WRIST   INDEX_TIP             0             8
# 25  A4_CONTOURS      Left       WRIST  MIDDLE_TIP             0            12
# 26  A4_CONTOURS      Left       WRIST    RING_TIP             0            16
# 27  A4_CONTOURS      Left       WRIST   PINKY_TIP             0            20
#
#     EUCLIDEAN_DISTANCE  PHYSICAL_DISTANCE  ERROR  ERROR_PCT
# 0                5.121                5.0   0.12       2.40
# 1                9.220               10.0  -0.78      -7.80
# 2                8.908                9.0  -0.09      -1.00
# 3                8.238                9.0  -0.76      -8.44
# 4                7.564                7.0   0.56       8.00
# 5                3.408                3.0   0.41      13.67
# 6                3.364                4.0  -0.64     -16.00
# 7                2.550                2.5   0.05       2.00
# 8                4.594                4.0   0.59      14.75
# 9                2.542                2.5   0.04       1.60
# 10               1.902                1.9   0.00       0.00
# 11               2.592                2.0   0.59      29.50
# 12               4.739                4.9  -0.16      -3.27
# 13               2.842                3.0  -0.16      -5.33
# 14               1.997                2.0  -0.00      -0.00
# 15               2.217                2.0   0.22      11.00
# 16               4.221                4.0   0.22       5.50
# 17               2.586                3.0  -0.41     -13.67
# 18               2.011                2.0   0.01       0.50
# 19               2.094                2.0   0.09       4.50
# 20               3.059                3.5  -0.44     -12.57
# 21               2.033                2.1  -0.07      -3.33
# 22               1.840                2.0  -0.16      -8.00
# 23              13.747               14.5  -0.75      -5.17
# 24              18.106               18.0   0.11       0.61
# 25              18.478               18.4   0.08       0.43
# 26              17.039               18.0  -0.96      -5.33
# 27              14.470               14.6  -0.13      -0.89
# 1. Hand Measurement File: C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data\patient12/output/hand_patient12_7_left_hand_measurements.csv
#
# 2. Landmark Measurement File: C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data\patient12/output/hand_patient12_7_left_landmark_measurements.csv
#
# 3. Coordinates Image File: C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data\patient12/output/hand_patient12_7_left_coordinates.jpeg
#
# 4. Contour Image File: C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data\patient12/output/hand_patient12_7_left_contours.jpeg
#
# 4. Landmarks Image File: C:\Users\Sumedha\BMEProject_Sudhir\LandmarkCaliper\src\data\patient12/output/hand_patient12_7_left_contours.jpeg
